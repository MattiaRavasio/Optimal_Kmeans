# %%
using CSV, Tables, LinearAlgebra, Random, Gurobi, JuMP, DataFrames, Statistics, MLJ, Plots, Clustering, Distances

# %%
"""
J is the number of points/record in the dataset
I is the number of clusters
D is the dimensionality of the points (number of features)
"""

function generate_points(I,J,D, std, seed = 1234)
    Random.seed!(seed);
    X, yy = make_blobs(J, D; centers=I, cluster_std=std)
    points = Matrix(DataFrame(X));
    min = minimum(points, dims=1);
    max = maximum(points, dims=1);
    points = (points .- min) ./ (max .- min);
    return points
end

function manhattan_optimal_kmenas(points, I, J, D)
    
    model = JuMP.Model(Gurobi.Optimizer);

    max_d = maximum(manhattan_distance(points))

    set_optimizer_attribute(model, "TimeLimit", 300)

    @variable(model, gamma[1:J]);
    @variable(model, z[1:J, 1:I],Bin);
    @variable(model, mu[1:J, 1:I] >=0);
    @variable(model, r[1:J, 1:I] >=0);
    @variable(model, max_d >= x[1:I, 1:D] >=0);
    @variable(model, y[1:J, 1:D, 1:I] >=0);

    @constraint(model, [j = 1:J], sum(z[j,:]) == 1);

    @constraint(model, [i=1:I, j=1:J, d=1:D], sum(y[j,d,i] for d=1:D) <= r[j,i]);
    @constraint(model, [i=1:I, j=1:J, d=1:D], y[j,d,i] >= x[i,d] - points[j,d]);
    @constraint(model, [i=1:I, j=1:J, d=1:D], y[j,d,i] >= -(x[i,d] - points[j,d]));

    @constraint(model, [i=1:I, j=1:J], gamma[j]>= r[j,i]-mu[j,i]);

    @constraint(model, [i = 1:I, j = 1:J], max_d*(1-z[j,i]) >= mu[j,i]);

    @objective(model, Min, sum(gamma[j] for j=1:J));

    optimize!(model);

    return value.(x), [argmax(value.(z)[i,:]) for i = 1:J], value.(gamma)  # centers, assignments, obj_value
end

function euclidean_optimal_kmenas(points,  I, J, D)
    
    model = JuMP.Model(Gurobi.Optimizer);

    max_d = maximum(euclidean_distance(points));

    set_optimizer_attribute(model, "TimeLimit", 300)

    @variable(model, gamma[1:J]);
    @variable(model, z[1:J, 1:I], Bin);
    @variable(model, mu[1:J, 1:I] >=0);
    @variable(model, r[1:J, 1:I] >=0);
    @variable(model, max_d >= x[1:I, 1:D] >=0);
    @variable(model, y[1:J, 1:D, 1:I] >=0);

    @constraint(model, [j = 1:J], sum(z[j,:]) == 1);

    @constraint(model, [i=1:I, j=1:J, d=1:D], sum(y[j,d,i] for d=1:D) <= r[j,i]);
    @constraint(model,[i=1:I, j=1:J, d=1:D], [y[j,d,i]; x[i,d] - points[j,d]] in SecondOrderCone())

    @constraint(model, [i=1:I, j=1:J], gamma[j]>= r[j,i]-mu[j,i]);

    @constraint(model, [i = 1:I, j = 1:J], max_d*(1-z[j,i]) >= mu[j,i]);

    @objective(model, Min, sum(gamma[j] for j=1:J));

    optimize!(model);

    return value.(x), [argmax(value.(z)[i,:]) for i = 1:J], value.(gamma)  # centers, assignments, obj_value
end

function mean_silhouette_score(assignment, counts, points)
    distances = pairwise(Euclidean(), points')
    return mean(silhouettes(assignment, counts, distances))
end

function euclidean_distance(points)
    n,m = size(points)
    distances = ones((n,n))
    for i in 1:n
        for j in 1:n
            distances[i,j] = sqrt(sum((points[i,:] - points[j,:]).^2))
        end
    end
    return distances
end

function manhattan_distance(points)
    n,m = size(points)
    distances = ones((n,n))
    for i in 1:n
        for j in 1:n
            distances[i,j] = sum(abs.(points[i,:] - points[j,:]))
        end
    end
    return distances
end

function manhattan_warm_start(points, I, J, D)
    
    model = JuMP.Model(Gurobi.Optimizer);

    max_d = maximum(manhattan_distance(points))

    set_optimizer_attribute(model, "TimeLimit", 300)

    @variable(model, gamma[1:J]);
    @variable(model, z[1:J, 1:I],Bin);
    @variable(model, mu[1:J, 1:I] >=0);
    @variable(model, r[1:J, 1:I] >=0);
    @variable(model, max_d >= x[1:I, 1:D] >=0);
    @variable(model, y[1:J, 1:D, 1:I] >=0);

    km = kmeans(points', I);
    x_warm = km.centers';
    z_warm = zeros(J,I);
    assignments = km.assignments;
    for i = 1:J
        z_warm[i,assignments[i]] = 1
    end

    set_start_value.(z, z_warm);
    set_start_value.(x, x_warm);

    @constraint(model, [j = 1:J], sum(z[j,:]) == 1);

    @constraint(model, [i=1:I, j=1:J, d=1:D], sum(y[j,d,i] for d=1:D) <= r[j,i]);
    @constraint(model, [i=1:I, j=1:J, d=1:D], y[j,d,i] >= x[i,d] - points[j,d]);
    @constraint(model, [i=1:I, j=1:J, d=1:D], y[j,d,i] >= -(x[i,d] - points[j,d]));

    @constraint(model, [i=1:I, j=1:J], gamma[j]>= r[j,i]-mu[j,i]);

    @constraint(model, [i = 1:I, j = 1:J], max_d*(1-z[j,i]) >= mu[j,i]);

    @objective(model, Min, sum(gamma[j] for j=1:J));

    optimize!(model);

    return value.(x), [argmax(value.(z)[i,:]) for i = 1:J], value.(gamma)  # centers, assignments, obj_value
end


function euclidean_warm_start(points,  I, J, D)
    
    model = JuMP.Model(Gurobi.Optimizer);

    max_d = maximum(euclidean_distance(points));

    set_optimizer_attribute(model, "TimeLimit", 300)

    @variable(model, gamma[1:J]);
    @variable(model, z[1:J, 1:I], Bin);
    @variable(model, mu[1:J, 1:I] >=0);
    @variable(model, r[1:J, 1:I] >=0);
    @variable(model, max_d >= x[1:I, 1:D] >=0);
    @variable(model, y[1:J, 1:D, 1:I] >=0);

    km = kmeans(points', I);
    x_warm = km.centers';
    z_warm = zeros(J,I);
    assignments = km.assignments;
    for i = 1:J
        z_warm[i,assignments[i]] = 1
    end

    @constraint(model, [j = 1:J], sum(z[j,:]) == 1);

    @constraint(model, [i=1:I, j=1:J, d=1:D], sum(y[j,d,i] for d=1:D) <= r[j,i]);
    @constraint(model,[i=1:I, j=1:J, d=1:D], [y[j,d,i]; x[i,d] - points[j,d]] in SecondOrderCone())

    @constraint(model, [i=1:I, j=1:J], gamma[j]>= r[j,i]-mu[j,i]);

    @constraint(model, [i = 1:I, j = 1:J], max_d*(1-z[j,i]) >= mu[j,i]);

    @objective(model, Min, sum(gamma[j] for j=1:J));

    optimize!(model);

    return value.(x), [argmax(value.(z)[i,:]) for i = 1:J], value.(gamma)  # centers, assignments, obj_value
end
# Out:
# euclidean_warm_start (generic function with 1 method)

# %% [markdown]
# ## Easy problem (var 1)

# %%
"""
J is the number of points/record in the dataset
I is the number of clusters
D is the dimensionality of the points (number of features)
"""

dim2_optimal_performance = []
dim2_kmeans_performance = []

for J in [20,50,100,300,500]
    for I in [2,3,4,5]
        for D = 2
            points = generate_points(I,J,D, ones(I));
            centroids, assignment, obj_value = manhattan_warm_start(points, I,J,D);
            #km = kmeans(points', I);
            push!(dim2_optimal_performance, mean_silhouette_score(assignment, counts(assignment), points))
            #assignments = km.assignments;
            #r = km.counts;
            #push!(dim2_kmeans_performance, mean_silhouette_score(assignments,r, points))
        end
    end
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-10-04
# Set parameter TimeLimit to value 300
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 340 rows, 224 columns and 800 nonzeros
# Model fingerprint: 0x50c6829f
# Variable types: 184 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [2e+00, 2e+00]
#   RHS range        [2e-02, 2e+00]
#
# User MIP start produced solution with objective 3.72261 (0.00s)
# Loaded user MIP start with objective 3.72261
#
# Presolve removed 170 rows and 124 columns
# Presolve time: 0.00s
# Presolved: 170 rows, 100 columns, 402 nonzeros
# Found heuristic solution: objective 3.7007202
# Variable types: 80 continuous, 20 integer (20 binary)
#
# Root relaxation: objective -3.769919e+00, 112 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -3.76992    0   20    3.70072   -3.76992   202%     -    0s
# H    0     0                       3.5100911   -0.44450   113%     -    0s
#      0     0   -0.44450    0   20    3.51009   -0.44450   113%     -    0s
#      0     0   -0.44450    0   20    3.51009   -0.44450   113%     -    0s
#      0     0   -0.18700    0   20    3.51009   -0.18700   105%     -    0s
#      0     0   -0.05565    0   20    3.51009   -0.05565   102%     -    0s
#      0     0    0.00672    0   20    3.51009    0.00672   100%     -    0s
#      0     0    0.02272    0   20    3.51009    0.02272  99.4%     -    0s
#      0     0    0.02272    0   20    3.51009    0.02272  99.4%     -    0s
#      0     0    0.10992    0   20    3.51009    0.10992  96.9%     -    0s
#      0     0    0.11482    0   20    3.51009    0.11482  96.7%     -    0s
#      0     0    0.11886    0   20    3.51009    0.11886  96.6%     -    0s
#      0     0    0.12441    0   20    3.51009    0.12441  96.5%     -    0s
#      0     0    0.12441    0   20    3.51009    0.12441  96.5%     -    0s
#      0     0    0.13244    0   20    3.51009    0.13244  96.2%     -    0s
#      0     0    0.13307    0   20    3.51009    0.13307  96.2%     -    0s
#      0     0    0.13355    0   20    3.51009    0.13355  96.2%     -    0s
#      0     0    0.13355    0   20    3.51009    0.13355  96.2%     -    0s
#      0     2    0.13355    0   20    3.51009    0.13355  96.2%     -    0s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 184
#   RLT: 1
#
# Explored 408 nodes (7386 simplex iterations) in 0.07 seconds (0.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.51009 3.70072 3.72261
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.510091114815e+00, best bound 3.510091114815e+00, gap 0.0000%
#
# User-callback calls 1237, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-10-04
# Set parameter TimeLimit to value 300
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 500 rows, 326 columns and 1200 nonzeros
# Model fingerprint: 0x0e73019a
# Variable types: 266 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [2e+00, 2e+00]
#   RHS range        [6e-02, 2e+00]
#
# User MIP start produced solution with objective 2.94737 (0.00s)
# Loaded user MIP start with objective 2.94737
#
# Presolve removed 216 rows and 147 columns
# Presolve time: 0.00s
# Presolved: 284 rows, 179 columns, 744 nonzeros
# Found heuristic solution: objective 3.2147074
# Variable types: 119 continuous, 60 integer (60 binary)
#
# Root relaxation: objective -1.022714e+01, 191 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  
# H13975  3908                       1.9265273    1.09091  43.4%  25.6    2s
# *22559  4747              56       1.9000188    1.33976  29.5%  28.5    4s
#  25631  4740    1.80554   40   21    1.90002    1.41757  25.4%  29.1    5s
#
# Cutting planes:
#   Gomory: 125
#   Implied bound: 2
#   Projected implied bound: 5
#   MIR: 130
#   Flow cover: 605
#   Inf proof: 215
#   RLT: 3
#   Relax-and-lift: 6
#
# Explored 40729 nodes (1209940 simplex iterations) in 8.71 seconds (18.67 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 1.90002 1.90002 1.92653 ... 2.85431
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.900018780298e+00, best bound 1.900018780298e+00, gap 0.0000%
#
# User-callback calls 84462, time in user-callback 0.01 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-10-04
# Set parameter TimeLimit to value 300
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 850 rows, 554 columns and 2000 nonzeros
# Model fingerprint: 0xbb4de4c9
# Variable types: 454 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [2e+00, 2e+00]
#   RHS range        [5e-02, 2e+00]
#
# User MIP start produced solution with objective 7.23126 (0.00s)
# Loaded user MIP start with objective 7.23126
#
# Presolve removed 410 rows and 304 columns
# Presolve time: 0.00s
# Presolved: 440 rows, 250 columns, 1032 nonzeros
# Found heuristic solution: objective 7.2130092
# Variable types: 200 continuous, 50 integer (50 binary)
#
# Root relaxation: objective -1.498493e+01, 294 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -14.98493    0   50    7.21301  -14.98493   308%     -    0s
#      0     0   -1.65190    0   50    7.21301   -1.65190   123%     -    0s
# H    0     0                       7.1791637   -1.26871   118%     -    0s
#      0     0   -1.26871    0   50    7.17916   -1.26871   118%     -    0s
#      0     0   -0.96571    0   50    7.17916   -0.96571   113%     -    0s
#      0     0   -0.52209    0   50    7.17916   -0.52209   107%     -    0s
#      0     0   -0.10216    0   49    7.17916   -0.10216   101%     -    0s
#      0     0    0.00286    0   50    7.17916    0.00286   100%     -    0s
#      0     0    0.00309    0   50    7.17916    0.00309   100%     -    0s
#      0     0    0.03277    0   50    7.17916    0.03277   100%     -    0s
#      0     0    0.03277    0   50    7.17916    0.03277   100%     -    0s
#      0     0    0.03277    0   50    7.17916    0.03277   100%     -    0s
#      0     0    0.03277    0   50    7.17916    0.03277   100%     -    0s
#      0     2    0.03277    0   50    7.17916    0.03277   100%     -    0s
#  16429  4303    6.98023   25   41    7.17916    5.40796  24.7%  53.9    5s
#
# Cutting planes:
#   Gomory: 29
#   MIR: 175
#   Flow cover: 610
#   RLT: 1
#
# Explored 26430 nodes (1367422 simplex iterations) in 7.07 seconds (18.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7.17916 7.23126
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.179163705995e+00, best bound 7.179163705995e+00, gap 0.0000%
#
# User-callback calls 54327, time in user-callback 0.01 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-10-04
# Set parameter TimeLimit to value 300
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1250 rows, 806 columns and 3000 nonzeros
# Model fingerprint: 0x14f87f29
# Variable types: 656 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [2e+00, 2e+00]
#   RHS range        [5e-02, 2e+00]
#
# User MIP start produced solution with objective 7.39439 (0.00s)
# Loaded user MIP start with objective 7.39439
#
# Presolve removed 516 rows and 357 columns
# Presolve time: 0.00s
# Presolved: 734 rows, 449 columns, 1914 nonzeros
# Found heuristic solution: objective 9.9855204
# Variable types: 299 continuous, 150 integer (150 binary)
#
# Root relaxation: objective -2.627639e+01, 459 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  
#  101295 51188    9.82842   37   88   13.42336    7.73250  42.4%   189  281s
#  103042 52401   10.50681   56   69   13.42336    7.75557  42.2%   189  287s
#  104396 53285   12.16760   46   79   13.42336    7.78036  42.0%   190  293s
#  105373 53956   10.60180   39   86   13.42336    7.79152  42.0%   190  296s
#  107251 54496   11.24586   42   83   13.42336    7.81462  41.8%   190  300s
#
# Cutting planes:
#   Gomory: 69
#   MIR: 302
#   Flow cover: 3596
#
# Explored 107301 nodes (20449808 simplex iterations) in 300.01 seconds (1086.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 13.4234 13.4658 13.4664
#
# Time limit reached
# Best objective 1.342336049033e+01, best bound 7.814615529717e+00, gap 41.7835%
#
# User-callback calls 246156, time in user-callback 0.86 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-10-04
# Set parameter TimeLimit to value 300
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2500 rows, 1606 columns and 6000 nonzeros
# Model fingerprint: 0xea771d38
# Variable types: 1306 continuous, 300 integer (300 binary)
# Coefficient statistics:
#
#
# Presolve time: 0.00s

# %%
dim2_optimal_performance = rename!(DataFrame(reshape(dim2_optimal_performance, (4,5)), :auto),:x1 => :"20", :x2 => :"50", :x3 => :"100", :x4 => :"300", :x5 => :"500")
dim2_optimal_performance[!,:centers] = ["2","3","4","5"];

#dim2_kmeans_performance = rename!(DataFrame(reshape(dim2_kmeans_performance, (4,5)), :auto),:x1 => :"20", :x2 => :"50", :x3 => :"100", :x4 => :"300", :x5 => :"500")
#dim2_kmeans_performance[!,:centers] = ["2","3","4","5"];


#CSV.write("Results/dim2_kmeans_performance.csv",dim2_kmeans_performance)
# Out:
# MethodError: no method matching reshape(::DataFrame, ::Tuple{Int64, Int64})
# Closest candidates are:
#   reshape(::OffsetArrays.OffsetArray, ::Tuple{Vararg{Int64, N}} where N) at /Users/iai/builds/e7x1Q22r/0/InterpretableAI/SystemImage/SysImgBuilder/.julia/packages/OffsetArrays/WvkHl/src/OffsetArrays.jl:380
#   reshape(::OffsetArrays.OffsetArray, ::Tuple{Vararg{Union{Colon, Int64}}}) at /Users/iai/builds/e7x1Q22r/0/InterpretableAI/SystemImage/SysImgBuilder/.julia/packages/OffsetArrays/WvkHl/src/OffsetArrays.jl:384
#   reshape(::OffsetArrays.OffsetArray, ::Tuple{Union{Integer, Base.OneTo}, Vararg{Union{Integer, Base.OneTo}}}) at /Users/iai/builds/e7x1Q22r/0/InterpretableAI/SystemImage/SysImgBuilder/.julia/packages/OffsetArrays/WvkHl/src/OffsetArrays.jl:379
#   ...
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:1
#  [2] eval
#    @ ./boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
dim2_optimal_performance
# Out:
# 4×6 DataFrame
#  Row │ 20        50        100       300       500       centers
#      │ Any       Any       Any       Any       Any       String
# ─────┼───────────────────────────────────────────────────────────
#    1 │ 0.756077  0.812402  0.822535  0.827132  0.831849  2
#    2 │ 0.749356  0.740422  0.770554  0.777486  0.76352   3
#    3 │ 0.699222  0.627198  0.664542  0.698736  0.633263  4
#    4 │ 0.593767  0.571434  0.616349  0.646467  0.649447  5

# %%
CSV.write("Results/dim2_warm_start_performance.csv",dim2_optimal_performance)
# Out:
# "Results/dim2_warm_start_performance.csv"
